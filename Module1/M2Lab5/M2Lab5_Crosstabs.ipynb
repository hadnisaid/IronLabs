# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median
from scipy import stats
# %matplotlib inline

# %% [markdown]
# ### 1. Import the moovies dataset

# %% [markdown]
# # https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset

# %%
df=pd.read_csv('Desktop/movie_metadata.csv')
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ### 2. Use crosstabs to show the number of moovies per country

# %%
pd.crosstab(df.country,df.country,margins=True)
# Out:
# country               Afghanistan  Argentina  Aruba  Australia  Bahamas  \
# country
# Afghanistan                     1          0      0          0        0
# Argentina                       0          4      0          0        0
# Aruba                           0          0      1          0        0
# Australia                       0          0      0         55        0
# Bahamas                         0          0      0          0        1
# ...                           ...        ...    ...        ...      ...
# UK                              0          0      0          0        0
# USA                             0          0      0          0        0
# United Arab Emirates            0          0      0          0        0
# West Germany                    0          0      0          0        0
# All                             1          4      1         55        1
#
# country               Belgium  Brazil  Bulgaria  Cambodia  Cameroon  ...  \
# ...

# %% [markdown]
# ### 3. Create a crosstab to show the number of films per director and genre splitted by country

# %%
a=pd.crosstab([df.director_name,df.genres],[df.country])
a
# Out:
# country                                                    Afghanistan  \
# director_name      genres
# A. Raven Cruz      Action|Adventure|Comedy|Fantasy|Sci-Fi            0
# Aaron Hann         Drama|Horror|Mystery|Sci-Fi|Thriller              0
# Aaron Schneider    Drama|Mystery                                     0
# Aaron Seltzer      Comedy|Romance                                    0
# Abel Ferrara       Crime|Drama                                       0
# ...                                                                ...
# Zoran Lisinac      Comedy|Music|Romance                              0
# Álex de la Iglesia Crime|Mystery|Thriller                            0
# Émile Gaudreault   Comedy|Drama                                      0
# Éric Tessier       Action|Drama|Horror|Thriller                      0
# Étienne Faure      Drama|Musical|Romance                             0
#
# country                                                    Argentina  Aruba  \
# ...

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 4. Average duration of filmes grouped by color

# %%
pd.crosstab(df.color,df.genres,df.duration,aggfunc='mean')
# Out:
# genres                Action  Action|Adventure  \
# color
#  Black and White  111.000000               NaN
# Color             107.444444        112.636364
#
# genres            Action|Adventure|Animation|Comedy|Crime|Family|Fantasy  \
# color
#  Black and White                                                NaN
# Color                                                          95.0
#
# genres            Action|Adventure|Animation|Comedy|Drama|Family|Sci-Fi  \
# color
#  Black and White                                                NaN
# Color                                                          96.0
#
# genres            Action|Adventure|Animation|Comedy|Family  \
# color
#  Black and White                                       NaN
# Color                                                 91.5
#
# genres            Action|Adventure|Animation|Comedy|Family|Fantasy  \
# color
#  Black and White                                               NaN
# ...

# %% [markdown]
# ### 5. Average number of likes per director (assuming that total film's likes are counted as a sum of actor's likes)

# %%
df['Total']=df['actor_1_facebook_likes']+df['actor_2_facebook_likes']+df['actor_3_facebook_likes']
df

s=pd.crosstab(df.director_name,df.country,values=df.Total,aggfunc=np.sum)
s
# Out:
# country             Afghanistan  Argentina  Aruba  Australia  Bahamas  \
# director_name
# A. Raven Cruz               NaN        NaN    NaN        NaN      NaN
# Aaron Hann                  NaN        NaN    NaN        NaN      NaN
# Aaron Schneider             NaN        NaN    NaN        NaN      NaN
# Aaron Seltzer               NaN        NaN    NaN        NaN      NaN
# Abel Ferrara                NaN        NaN    NaN        NaN      NaN
# ...                         ...        ...    ...        ...      ...
# Zoran Lisinac               NaN        NaN    NaN        NaN      NaN
# Álex de la Iglesia          NaN        NaN    NaN        NaN      NaN
# Émile Gaudreault            NaN        NaN    NaN        NaN      NaN
# Éric Tessier                NaN        NaN    NaN        NaN      NaN
# Étienne Faure               NaN        NaN    NaN        NaN      NaN
#
# country             Belgium  Brazil  Bulgaria  Cambodia  Cameroon  ...  Spain  \
# ...
