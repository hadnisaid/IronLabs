# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
pip install stackapi
# Out:
# Collecting stackapi
#   Downloading StackAPI-0.2.0.tar.gz (5.6 kB)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from stackapi) (2.27.1)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from stackapi) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from requests->stackapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->stackapi) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->stackapi) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->stackapi) (1.26.9)
# Building wheels for collected packages: stackapi
#   Building wheel for stackapi (setup.py): started
#   Building wheel for stackapi (setup.py): finished with status 'done'
#   Created wheel for stackapi: filename=StackAPI-0.2.0-py3-none-any.whl size=5858 sha256=4f944cea498f4a79782b8f7d3498ba20779a1b387acc680db7acf3c603f6cb31
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\de\58\fe\8bab7cf44d8b0bf32e46f1715df2ba8c97d475de95a20985ac
# Successfully built stackapi
# Installing collected packages: stackapi
# Successfully installed stackapi-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
from stackapi import StackAPI
import requests
import json

# %%
response=requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")
print(response.json())
# Out:
# {'items': [{'tags': ['postgresql', 'crosstab'], 'owner': {'account_id': 25955245, 'reputation': 1, 'user_id': 19672681, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmnle6uwxROTcKVGtuWneUMN7Eb4ITXEfG4m03yd=k-s256', 'display_name': 'sss21', 'link': 'https://stackoverflow.com/users/19672681/sss21'}, 'is_answered': False, 'view_count': 14, 'answer_count': 0, 'score': 0, 'last_activity_date': 1659443300, 'creation_date': 1659439693, 'last_edit_date': 1659443300, 'question_id': 73206778, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73206778/converting-multi-row-to-a-single-row-in-new-column-is-postgressql', 'title': 'converting multi row to a single row in new column is PostgresSQL'}, {'tags': ['angular', 'overlapping', 'mat-form-field'], 'owner': {'account_id': 10728829, 'reputation': 11, 'user_id': 7895542, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/d9e4d68bda31f78f230ff6dc210842c0?s=256&d=identicon&r=PG&f=1', 'display_name': 'J.N.', 'link': 'https://stackoverflow.com/users/7895542/j-n'}, 'is_answered': False, 'view_count': 24, 'answer_count': 0, 'score': 0, 'last_activity_date': 1659443299, 'creation_date': 1659366438, 'last_edit_date': 1659443299, 'question_id': 73195812, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73195812/mat-form-field-overlapping-into-button-below', 'title': 'mat-form-field overlapping into button below'}, {'tags': ['javascript', 'arrays', 'sorting'], 'owner': {'account_id': 254444, 'reputation': 2391, 'user_id': 533853, 'user_type': 'registered', 'accept_rate': 55, 'profile_image': 'https://www.gravatar.com/avatar/77fb41585800aa033e7a40ef6a0b870c?s=256&d=identicon&r=PG', 'display_name': 'Mark', 'link': 'https://stackoverflow.com/users/533853/mark'}, 'is_answered': True, 'view_count': 107836, 'accepted_answer_id': 6130014, 'answer_count': 18, 'score': 119, 'last_activity_date': 1659443298, 'creation_date': 1306352537, 'last_edit_date': 1639672984, 'question_id': 6129952, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/6129952/sort-javascript-array-by-two-numeric-fields', 'title': 'sort Javascript array by two numeric fields'}, {'tags': ['html', 'accessibility'], 'owner': {'account_id': 18131005, 'reputation': 51, 'user_id': 13186118, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/1fa6e05f0470da9be1984dd44f91d7e6?s=256&d=identicon&r=PG&f=1', 'display_name': 'Peter', 'link': 'https://stackoverflow.com/users/13186118/peter'}, 'is_answered': False, 'view_count': 14, 'answer_count': 1, 'score': 0, 'last_activity_date': 1659443296, 'creation_date': 1659430914, 'question_id': 73204746, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73204746/dropdown-switcher-for-large-tables-accessibility-for-screen-reader-users', 'title': 'Dropdown switcher for large tables - accessibility for screen reader users'}, {'tags': ['java', 'multithreading', 'spring-boot', 'scheduled-tasks'], 'owner': {'account_id': 20511311, 'reputation': 433, 'user_id': 15053014, 'user_type': 'registered', 'profile_image': 'https://i.stack.imgur.com/1YZmR.jpg?s=256&g=1', 'display_name': 'ima.technophyle', 'link': 'https://stackoverflow.com/users/15053014/ima-technophyle'}, 'is_answered': False, 'view_count': 13, 'answer_count': 0, 'score': 0, 'last_activity_date': 1659443294, 'creation_date': 1659442062, 'question_id': 73207292, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73207292/java-concurrent-executor-service-returning-inconsistent-responses', 'title': 'Java Concurrent Executor Service returning inconsistent responses'}, {'tags': ['lte', 'apn', 'ims'], 'owner': {'account_id': 5141433, 'reputation': 316, 'user_id': 4118695, 'user_type': 'registered', 'profile_image': 'https://lh6.googleusercontent.com/-lJKWd1Hy4_0/AAAAAAAAAAI/AAAAAAAAAFg/1Y8PIvs_W0w/photo.jpg?sz=256', 'display_ ...

# %%
results=(response.json())

# %%
res=response.json()

# %%
l=res["items"]
l
# Out:
# [{'tags': ['jira-rest-api', 'python-jira'],
#   'owner': {'account_id': 20035002,
#    'reputation': 69,
#    'user_id': 14686925,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/d583085019d36a0a7585d57fc3f9ae00?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'User1',
#    'link': 'https://stackoverflow.com/users/14686925/user1'},
#   'is_answered': False,
#   'view_count': 1,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443723,
#   'creation_date': 1659443723,
#   'question_id': 73207661,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207661/add-value-to-select-list-in-jira-cloud-using-python-and-api',
#   'title': 'Add value to select list in Jira cloud using python and API'},
#  {'tags': ['html', 'css', 'font-size', 'line-height'],
#   'owner': {'account_id': 25730239,
#    'reputation': 109,
#    'user_id': 19485937,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/4ffcacc6da2f34d849a819df4e87af5e?s=256&d=identicon&r=PG',
#    'display_name': 'stackdeveloper',
#    'link': 'https://stackoverflow.com/users/19485937/stackdeveloper'},
#   'is_answered': False,
#   'view_count': 58,
#   'answer_count': 0,
#   'score': 1,
#   'last_activity_date': 1659443721,
#   'creation_date': 1659279973,
#   'last_edit_date': 1659443721,
#   'question_id': 73184405,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73184405/why-font-size-isnt-equal-to-the-height-so-in-the-right-if-the-span-is-2r',
#   'title': 'why `font-size` isn&#39;t equal to the `height`? so in the right if the &lt;span&gt; is 2rem, on the right I can have 2 small &lt;span&gt;s of 1rem each one'},
#  {'tags': ['flutter'],
#   'owner': {'account_id': 25957240,
#    'reputation': 1,
#    'user_id': 19674422,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmn9AQz0YGFIaBB-t85wt-tW8z_cTxaXB6FecOW2=k-s256',
#    'display_name': 'whynot11',
#    'link': 'https://stackoverflow.com/users/19674422/whynot11'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443719,
#   'creation_date': 1659443719,
#   'question_id': 73207660,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207660/flutter-how-to-close-alertdialog-from-another-file',
#   'title': 'Flutter : How to close alertdialog from another file'},
#  {'tags': ['java'],
#   'owner': {'account_id': 23646042,
#    'reputation': 175,
#    'user_id': 18197654,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/dSgqg.png?s=256&g=1',
#    'display_name': 'xtay2',
#    'link': 'https://stackoverflow.com/users/18197654/xtay2'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443715,
#   'creation_date': 1659443715,
#   'question_id': 73207659,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207659/does-classgetdeclaredfields-return-synthetic-fields',
#   'title': 'Does class#getDeclaredFields() return synthetic fields?'},
#  {'tags': ['flutter', 'visual-studio-code', 'command'],
#   'owner': {'account_id': 25952287,
#    'reputation': 11,
#    'user_id': 19670142,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmm4t1eDOyk39MbzKqz_JYkjFWEufnxhQjJihcU1=k-s256',
#    'display_name': 'Ye Ah',
#    'link': 'https://stackoverflow.com/users/19670142/ye-ah'},
#   'is_answered': False,
#   'view_count': 24,
#   'answer_count': 2,
#   'score': 1,
#   'last_activity_date': 1659443714,
#   'creation_date': 1659396593,
#   'last_edit_date': 1659396623,
#   'question_id': 73200508,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73200508/unable-to-run-flutter-command-on-vs-code-terminal',
#   'title': 'Unable to run flutter command on VS code terminal'},
#  {'tags': ['python'],
#   'owner': {'account_id': 10363548,
#    'reputation': 127,
#    'user_id': 7643306,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/add76476f3954ffde33be43f76f16890?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'diego',
#    'link': 'https://stackoverflow.com/users/7643306/diego'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443713,
#   'creation_date': 1659443713,
#   'question_id': 73207657,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207657/generate-identifier-for-value-in-python',
#   'title': 'Generate identifier for value in python'},
#  {'tags': ['python', 'bloomberg'],
#   'owner': {'account_id': 25957548,
#    'reputation': 1,
#    'user_id': 19674680,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmmhK1SXJm7NcWoqQ2m7ewQ8P0lgdlXART3a0qtp=k-s256',
#    'display_name': 'Robert',
#    'link': 'https://stackoverflow.com/users/19674680/robert'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443712,
#   'creation_date': 1659443712,
#   'question_id': 73207656,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207656/how-to-get-best-sales-from-bloomberg-for-next-2-years-via-python',
#   'title': 'How to get BEST_Sales from Bloomberg for next 2 years via python?'},
#  {'tags': ['asp.net', 'linq', 'linq-to-sql'],
#   'owner': {'account_id': 13679240,
#    'reputation': 1,
#    'user_id': 9869990,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/npYg5.jpg?s=256&g=1',
#    'display_name': 'Akshay Meshram',
#    'link': 'https://stackoverflow.com/users/9869990/akshay-meshram'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443708,
#   'creation_date': 1659443708,
#   'question_id': 73207655,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207655/firstordefault-linq-query-with-condition',
#   'title': 'Firstordefault linq query with condition'},
#  {'tags': ['amazon-web-services',
#    'aws-lambda',
#    'aws-api-gateway',
#    'aws-fargate'],
#   'owner': {'account_id': 347882,
#    'reputation': 452,
#    'user_id': 682264,
#    'user_type': 'registered',
#    'accept_rate': 0,
#    'profile_image': 'https://www.gravatar.com/avatar/bb306d27596b4563d110459c8b583a28?s=256&d=identicon&r=PG',
#    'display_name': 'museshad',
#    'link': 'https://stackoverflow.com/users/682264/museshad'},
#   'is_answered': False,
#   'view_count': 11,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1659443707,
#   'creation_date': 1659432891,
#   'question_id': 73205218,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73205218/aws-fargate-suitable-for-synchronous-api',
#   'title': 'AWS Fargate suitable for synchronous API?'},
#  {'tags': ['flutter'],
#   'owner': {'account_id': 3031154,
#    'reputation': 2075,
#    'user_id': 2570135,
#    'user_type': 'registered',
#    'accept_rate': 62,
#    'profile_image': 'https://www.gravatar.com/avatar/dd78f6ab7ada3da0f0958b1b653cec1b?s=256&d=identicon&r=PG',
#    'display_name': 'user2570135',
#    'link': 'https://stackoverflow.com/users/2570135/user2570135'},
#   'is_answered': False,
#   'view_count': 21,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1659443706,
#   'creation_date': 1659442704,
#   'question_id': 73207425,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207425/create-overlapping-image-in-flutter',
#   'title': 'Create overlapping image in flutter'},
#  {'tags': ['trading', 'tradingview-api', 'stockquotes'],
#   'owner': {'account_id': 16424939,
#    'reputation': 1,
#    'user_id': 12281251,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/7f0309e1e3bce8d953b6ca19b2040737?s=256&d=identicon&r=PG',
#    'display_name': 'ATUL',
#    'link': 'https://stackoverflow.com/users/12281251/atul'},
#   'is_answered': False,
#   'view_count': 6,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1659443704,
#   'creation_date': 1659368429,
#   'question_id': 73196262,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73196262/what-is-tvc-in-tvcukx-symbol-on-tradingview',
#   'title': 'What is TVC in &quot;TVC:UKX&quot; symbol on tradingview?'},
#  {'tags': ['apache-spark', 'pyspark', 'apache-spark-sql'],
#   'owner': {'account_id': 22108384,
#    'reputation': 23,
#    'user_id': 16363630,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GgOu1WcoGYs2XApd59nF0KZ0fa1z9jtrKwcWXWTIw=k-s256',
#    'display_name': 'Akash Pujara',
#    'link': 'https://stackoverflow.com/users/16363630/akash-pujara'},
#   'is_answered': False,
#   'view_count': 9,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1659443698,
#   'creation_date': 1659442465,
#   'question_id': 73207365,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207365/how-to-remove-rows-from-a-dataframe-based-on-keyword-found-in-a-particular-colum',
#   'title': 'How to remove rows from a dataframe based on keyword found in a particular columns in pyspark'},
#  {'tags': ['python-3.x', 'api', 'selenium', 'automation', 'whatsapp'],
#   'owner': {'account_id': 20852529,
#    'reputation': 23,
#    'user_id': 15316712,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/42cfed07750486b54844ebdb80305a26?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Princeofcoding',
#    'link': 'https://stackoverflow.com/users/15316712/princeofcoding'},
#   'is_answered': False,
#   'view_count': 32,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1659443685,
#   'creation_date': 1659374910,
#   'question_id': 73197468,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73197468/https-web-whatsapp-com-sendphone-is-showing-error',
#   'title': 'https://web.whatsapp.com/send?phone= is showing error'},
#  {'tags': ['r', 'join'],
#   'owner': {'account_id': 4669825,
#    'reputation': 21,
#    'user_id': 15378936,
#    'user_type': 'registered',
#    'profile_image': 'https://graph.facebook.com/1260427839/picture?type=large',
#    'display_name': 'user11849',
#    'link': 'https://stackoverflow.com/users/15378936/user11849'},
#   'is_answered': False,
#   'view_count': 20,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1659443681,
#   'creation_date': 1659441115,
#   'question_id': 73207078,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207078/update-table-with-another-table-values-several-columns-in-r',
#   'title': 'Update table with another table values (several columns) in R'},
#  {'tags': ['java',
#    'android',
#    'scrollview',
#    'android-custom-view',
#    'android-constraintlayout'],
#   'owner': {'account_id': 8043129,
#    'reputation': 1,
#    'user_id': 13539379,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/d58ee815d6cd82c636cef2b2e724acca?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'user547654',
#    'link': 'https://stackoverflow.com/users/13539379/user547654'},
#   'is_answered': False,
#   'view_count': 21,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443679,
#   'creation_date': 1659386726,
#   'last_edit_date': 1659443679,
#   'question_id': 73199415,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73199415/custom-view-with-constraint',
#   'title': 'Custom View with Constraint'},
#  {'tags': ['php', 'mysql'],
#   'owner': {'account_id': 25957521,
#    'reputation': 1,
#    'user_id': 19674659,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AFdZucp_ZHIClCn2Rpj4aBATK6qS7Qp2o4Qg7l_OINuv=k-s256',
#    'display_name': 'Narsi Choyal',
#    'link': 'https://stackoverflow.com/users/19674659/narsi-choyal'},
#   'is_answered': False,
#   'view_count': 5,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443670,
#   'creation_date': 1659443670,
#   'question_id': 73207649,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207649/mysql-fetch-array-not-woking-with-all-record-with-while-loop',
#   'title': 'mysql_fetch_array not woking with all record with while loop'},
#  {'tags': ['ios', 'swift', 'uislider'],
#   'owner': {'account_id': 12614873,
#    'reputation': 2472,
#    'user_id': 14087244,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/-dShOOrMVJYA/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucnzKpCbvkjDj5GWHB1_j6Iv_CBEFw/photo.jpg?sz=256',
#    'display_name': 'Mickael Belhassen',
#    'link': 'https://stackoverflow.com/users/14087244/mickael-belhassen'},
#   'is_answered': True,
#   'view_count': 1728,
#   'accepted_answer_id': 59949125,
#   'answer_count': 5,
#   'score': 2,
#   'last_activity_date': 1659443667,
#   'creation_date': 1580214069,
#   'last_edit_date': 1580287909,
#   'question_id': 59948677,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/59948677/swift-uislider-one-side-of-track-not-rounded',
#   'title': 'Swift: UISlider one side of track not rounded'},
#  {'tags': ['swiftui'],
#   'owner': {'account_id': 25956974,
#    'reputation': 1,
#    'user_id': 19674190,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AFdZucpDHD8tD-2tgUxL3arwDonViVfLqVY9C61PgmioUA=k-s256',
#    'display_name': 'Kimmo Keskinen',
#    'link': 'https://stackoverflow.com/users/19674190/kimmo-keskinen'},
#   'is_answered': False,
#   'view_count': 24,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1659443666,
#   'creation_date': 1659439801,
#   'last_edit_date': 1659440235,
#   'question_id': 73206804,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73206804/no-exact-matches-in-call-initializer',
#   'title': 'No exact matches in call initializer'},
#  {'tags': ['flutter',
#    'firebase',
#    'google-cloud-firestore',
#    'stream',
#    'flutter-getx'],
#   'owner': {'account_id': 18627142,
#    'reputation': 43,
#    'user_id': 13575992,
#    'user_type': 'registered',
#    'profile_image': 'https://lh4.googleusercontent.com/-k7Zu0L4EFoE/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclfT7VYuhvojE0649nw-vo5oghD5A/photo.jpg?sz=256',
#    'display_name': 'Michael Ogundipe',
#    'link': 'https://stackoverflow.com/users/13575992/michael-ogundipe'},
#   'is_answered': False,
#   'view_count': 26,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1659443658,
#   'creation_date': 1659429434,
#   'last_edit_date': 1659443658,
#   'question_id': 73204411,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73204411/using-getx-bind-stream-with-firebase-firestore',
#   'title': 'Using GetX Bind Stream with Firebase Firestore'},
#  {'tags': ['ios', 'xcode', 'flutter', 'codemagic'],
#   'owner': {'account_id': 23029121,
#    'reputation': 21,
#    'user_id': 17148883,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/OUaJv.png?s=256&g=1',
#    'display_name': 'the_conqueror',
#    'link': 'https://stackoverflow.com/users/17148883/the-conqueror'},
#   'is_answered': False,
#   'view_count': 194,
#   'answer_count': 1,
#   'score': 1,
#   'last_activity_date': 1659443657,
#   'creation_date': 1651768675,
#   'question_id': 72130732,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/72130732/codemagic-ios-build-fail-flutter-udid',
#   'title': 'Codemagic IOS build fail flutter_udid'},
#  {'tags': ['mysql', 'sql', 'join', 'group-by'],
#   'owner': {'account_id': 6799176,
#    'reputation': 1006,
#    'user_id': 5233151,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/FIWYl.jpg?s=256&g=1',
#    'display_name': 'Vikas Chauhan',
#    'link': 'https://stackoverflow.com/users/5233151/vikas-chauhan'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443657,
#   'creation_date': 1659443657,
#   'question_id': 73207645,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207645/get-most-recent-records-from-the-table-if-a-alert-status-is-present-otherwise',
#   'title': 'Get most recent records from the table if a &#39;ALERT&#39; status is present otherwise most recent record with &#39;OK&#39; Status - Mysql'},
#  {'tags': ['flutter'],
#   'owner': {'account_id': 24703163,
#    'reputation': 7,
#    'user_id': 18594279,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJwoQyikx8UGuH5Ro9O5pojF4GI7PlRQeZpTR9nD=k-s256',
#    'display_name': 'Ae Gg',
#    'link': 'https://stackoverflow.com/users/18594279/ae-gg'},
#   'is_answered': False,
#   'view_count': 21,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1659443649,
#   'creation_date': 1659441536,
#   'question_id': 73207166,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207166/how-to-generate-uuid-every-time-when-user-typing-in-a-textfield',
#   'title': 'How to generate uuid every time when user typing in a textfield?'},
#  {'tags': ['flutter', 'flutter-layout'],
#   'owner': {'account_id': 14748176,
#    'reputation': 5,
#    'user_id': 10650971,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/28304b7a481cd0754554bd084eb34d38?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'iosNewbie',
#    'link': 'https://stackoverflow.com/users/10650971/iosnewbie'},
#   'is_answered': False,
#   'view_count': 22,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1659443644,
#   'creation_date': 1659437432,
#   'last_edit_date': 1659443644,
#   'question_id': 73206265,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73206265/flutter-create-grouped-listview-from-map-string-object',
#   'title': 'Flutter: Create Grouped Listview from Map &lt;String, Object&gt;'},
#  {'tags': ['angular', 'unit-testing', 'karma-jasmine', 'ng-apexcharts'],
#   'owner': {'account_id': 25936655,
#    'reputation': 1,
#    'user_id': 19656799,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmkhFJO_a18ACItsGbZ8kxspvxjtz5sYjAu137V_=k-s256',
#    'display_name': 'sammy lee',
#    'link': 'https://stackoverflow.com/users/19656799/sammy-lee'},
#   'is_answered': False,
#   'view_count': 9,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443642,
#   'creation_date': 1659434299,
#   'last_edit_date': 1659443642,
#   'question_id': 73205556,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73205556/unit-testing-with-jasmine-karma-on-an-angular-apex-charts-component',
#   'title': 'Unit-testing with Jasmine/Karma on an Angular Apex Charts component'},
#  {'tags': ['ibm-mq'],
#   'owner': {'account_id': 12031967,
#    'reputation': 11,
#    'user_id': 8801920,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/df6742277741188c53337d674d29ae92?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Florian NO&#203;L',
#    'link': 'https://stackoverflow.com/users/8801920/florian-no%c3%8bl'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443640,
#   'creation_date': 1659443640,
#   'question_id': 73207643,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207643/mq-client-key-repository-questions',
#   'title': 'MQ client key repository questions'},
#  {'tags': ['python', 'python-3.x', 'string'],
#   'owner': {'account_id': 25481131,
#    'reputation': 19,
#    'user_id': 19277475,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/3a9cba699daa28ba8e6c98212f58a283?s=256&d=identicon&r=PG',
#    'display_name': 'newbiee',
#    'link': 'https://stackoverflow.com/users/19277475/newbiee'},
#   'is_answered': False,
#   'view_count': 8,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443634,
#   'creation_date': 1659443545,
#   'last_edit_date': 1659443634,
#   'question_id': 73207617,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207617/remove-file-name-and-extension-from-path-and-just-keep-path',
#   'title': 'Remove file name and extension from path and just keep path'},
#  {'tags': ['r', 'aggregate'],
#   'owner': {'account_id': 24111700,
#    'reputation': 193,
#    'user_id': 18143306,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/7SO0U.jpg?s=256&g=1',
#    'display_name': 'Melanie Baker',
#    'link': 'https://stackoverflow.com/users/18143306/melanie-baker'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443631,
#   'creation_date': 1659443631,
#   'question_id': 73207642,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207642/r-calculate-how-many-values-used-to-calculate-mean-in-aggregate-function',
#   'title': 'R calculate how many values used to calculate mean in aggregate function'},
#  {'tags': ['python', 'autocomplete', 'realsense'],
#   'owner': {'account_id': 25957365,
#    'reputation': 1,
#    'user_id': 19674532,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/9a7f79d722da21b6bdf4a98a50c03b3a?s=256&d=identicon&r=PG',
#    'display_name': 'Yavuz Selim',
#    'link': 'https://stackoverflow.com/users/19674532/yavuz-selim'},
#   'is_answered': False,
#   'view_count': 10,
#   'answer_count': 1,
#   'score': -1,
#   'last_activity_date': 1659443628,
#   'creation_date': 1659442699,
#   'last_edit_date': 1659442716,
#   'question_id': 73207423,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207423/autocompletions-in-ides-dont-work-for-cv2',
#   'title': 'Autocompletions in IDEs don&#39;t work for cv2'},
#  {'tags': ['pip', 'lib'],
#   'owner': {'account_id': 19855066,
#    'reputation': 11,
#    'user_id': 14544712,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gj7LTYhk_ta-Bz31-I19UX9RQd3jsM3GcyRFT1ySQ=k-s256',
#    'display_name': 'Syed Ziauddin',
#    'link': 'https://stackoverflow.com/users/14544712/syed-ziauddin'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443628,
#   'creation_date': 1659443628,
#   'question_id': 73207641,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207641/couldnt-import-package-when-i-download-it-using-pip-download-name-of-package',
#   'title': 'Couldn&#39;t import package when I download it using pip download &lt;name_of_package&gt; ? It went to Lib and I am unable to import it'},
#  {'tags': ['databricks', 'aws-databricks', 'aws-private-link'],
#   'owner': {'account_id': 25957162,
#    'reputation': 1,
#    'user_id': 19674355,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/15c559f4a2f2e543942762dd7d985a24?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'dev_lite_s',
#    'link': 'https://stackoverflow.com/users/19674355/dev-lite-s'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659443621,
#   'creation_date': 1659443621,
#   'question_id': 73207640,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73207640/unable-to-create-a-cluster-in-databricks-on-a-customer-managed-vpc-private-link',
#   'title': 'Unable to create a cluster in databricks on a customer managed vpc (private link enabled) - AWS'}]

# %%
for i in results["items"]:
    print(i["title"])
# Out:
# Add value to select list in Jira cloud using python and API
# why `font-size` isn&#39;t equal to the `height`? so in the right if the &lt;span&gt; is 2rem, on the right I can have 2 small &lt;span&gt;s of 1rem each one
# Flutter : How to close alertdialog from another file
# Does class#getDeclaredFields() return synthetic fields?
# Unable to run flutter command on VS code terminal
# Generate identifier for value in python
# How to get BEST_Sales from Bloomberg for next 2 years via python?
# Firstordefault linq query with condition
# AWS Fargate suitable for synchronous API?
# Create overlapping image in flutter
# What is TVC in &quot;TVC:UKX&quot; symbol on tradingview?
# How to remove rows from a dataframe based on keyword found in a particular columns in pyspark
# https://web.whatsapp.com/send?phone= is showing error
# Update table with another table values (several columns) in R
# Custom View with Constraint
# mysql_fetch_array not woking with all record with while loop
# Swift: UISlider one side of track not rounded
# No exact matches in call initializer
# Using GetX Bind Stream with Firebase Firestore
# Codemagic IOS build fail flutter_udid
# Get most recent records from the table if a &#39;ALERT&#39; status is present otherwise most recent record with &#39;OK&#39; Status - Mysql
# How to generate uuid every time when user typing in a textfield?
# Flutter: Create Grouped Listview from Map &lt;String, Object&gt;
# Unit-testing with Jasmine/Karma on an Angular Apex Charts component
# MQ client key repository questions
# Remove file name and extension from path and just keep path
# R calculate how many values used to calculate mean in aggregate function
# Autocompletions in IDEs don&#39;t work for cv2
# Couldn&#39;t import package when I download it using pip download &lt;name_of_package&gt; ? It went to Lib and I am unable to import it
# Unable to create a cluster in databricks on a customer managed vpc (private link enabled) - AWS

# %%
for i in results["items"]:
    print(i["title"],i["score"])
# Out:
# Add value to select list in Jira cloud using python and API 0
# why `font-size` isn&#39;t equal to the `height`? so in the right if the &lt;span&gt; is 2rem, on the right I can have 2 small &lt;span&gt;s of 1rem each one 1
# Flutter : How to close alertdialog from another file 0
# Does class#getDeclaredFields() return synthetic fields? 0
# Unable to run flutter command on VS code terminal 1
# Generate identifier for value in python 0
# How to get BEST_Sales from Bloomberg for next 2 years via python? 0
# Firstordefault linq query with condition 0
# AWS Fargate suitable for synchronous API? 0
# Create overlapping image in flutter 0
# What is TVC in &quot;TVC:UKX&quot; symbol on tradingview? 0
# How to remove rows from a dataframe based on keyword found in a particular columns in pyspark 0
# https://web.whatsapp.com/send?phone= is showing error 0
# Update table with another table values (several columns) in R 0
# Custom View with Constraint 0
# mysql_fetch_array not woking with all record with while loop 0
# Swift: UISlider one side of track not rounded 2
# No exact matches in call initializer 0
# Using GetX Bind Stream with Firebase Firestore 0
# Codemagic IOS build fail flutter_udid 1
# Get most recent records from the table if a &#39;ALERT&#39; status is present otherwise most recent record with &#39;OK&#39; Status - Mysql 0
# How to generate uuid every time when user typing in a textfield? 0
# Flutter: Create Grouped Listview from Map &lt;String, Object&gt; 0
# Unit-testing with Jasmine/Karma on an Angular Apex Charts component 0
# MQ client key repository questions 0
# Remove file name and extension from path and just keep path 0
# R calculate how many values used to calculate mean in aggregate function 0
# Autocompletions in IDEs don&#39;t work for cv2 -1
# Couldn&#39;t import package when I download it using pip download &lt;name_of_package&gt; ? It went to Lib and I am unable to import it 0
# Unable to create a cluster in databricks on a customer managed vpc (private link enabled) - AWS 0

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
for i in results["items"]:
    if "python" in (i["tags"]):
        print(i["title"])
# Out:
# Generate identifier for value in python
# How to get BEST_Sales from Bloomberg for next 2 years via python?
# Remove file name and extension from path and just keep path
# Autocompletions in IDEs don&#39;t work for cv2

# %%
l=[]
for i in results["items"]:
    l.append(i["score"])
max(l)
# Out:
# 2

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
for i in results["items"]:
    if "6784" in (i["tags"]):
        print(i["title"])
        
question_id

# %%
for i in results["items"]:
    print(i["question_id"],i["title"])
# Out:
# 73207661 Add value to select list in Jira cloud using python and API
# 73184405 why `font-size` isn&#39;t equal to the `height`? so in the right if the &lt;span&gt; is 2rem, on the right I can have 2 small &lt;span&gt;s of 1rem each one
# 73207660 Flutter : How to close alertdialog from another file
# 73207659 Does class#getDeclaredFields() return synthetic fields?
# 73200508 Unable to run flutter command on VS code terminal
# 73207657 Generate identifier for value in python
# 73207656 How to get BEST_Sales from Bloomberg for next 2 years via python?
# 73207655 Firstordefault linq query with condition
# 73205218 AWS Fargate suitable for synchronous API?
# 73207425 Create overlapping image in flutter
# 73196262 What is TVC in &quot;TVC:UKX&quot; symbol on tradingview?
# 73207365 How to remove rows from a dataframe based on keyword found in a particular columns in pyspark
# 73197468 https://web.whatsapp.com/send?phone= is showing error
# 73207078 Update table with another table values (several columns) in R
# 73199415 Custom View with Constraint
# 73207649 mysql_fetch_array not woking with all record with while loop
# 59948677 Swift: UISlider one side of track not rounded
# 73206804 No exact matches in call initializer
# 73204411 Using GetX Bind Stream with Firebase Firestore
# 72130732 Codemagic IOS build fail flutter_udid
# 73207645 Get most recent records from the table if a &#39;ALERT&#39; status is present otherwise most recent record with &#39;OK&#39; Status - Mysql
# 73207166 How to generate uuid every time when user typing in a textfield?
# 73206265 Flutter: Create Grouped Listview from Map &lt;String, Object&gt;
# 73205556 Unit-testing with Jasmine/Karma on an Angular Apex Charts component
# 73207643 MQ client key repository questions
# 73207617 Remove file name and extension from path and just keep path
# 73207642 R calculate how many values used to calculate mean in aggregate function
# 73207423 Autocompletions in IDEs don&#39;t work for cv2
# 73207641 Couldn&#39;t import package when I download it using pip download &lt;name_of_package&gt; ? It went to Lib and I am unable to import it
# 73207640 Unable to create a cluster in databricks on a customer managed vpc (private link enabled) - AWS
